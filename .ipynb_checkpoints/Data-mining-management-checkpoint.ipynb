# %% [markdown]
# # Data mining using csv data
#
# we will use K to the Nearest Neighbor in our analysis(KNN)
#
# 1. end to end workflow
# 2. Getting the data ready
# 3. Choose algorithm for our problem
# 4. fit the model
# 5. Evaluate the model
# 6. improve the model
# 7. Save and load a traind model
# 8. Put it all together

# %% [markdown]
#  ## end to end workflow

# %%
# Get thE data ready

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
dataset_mining = pd.read_csv("data/data_dataset.csv")
dataset_mining.head(20)
# Out:
#     CustomerID Gender Car Type   Shirt Size Class
# 0            1      M   Family        Small    C0
# 1            2      M   Sports       Medium    C0
# 2            3      M   Sports       Medium    C0
# 3            4      M   Sports        Large    C0
# 4            5      M   Sports  Extra Large    C0
# 5            6      M   Sports  Extra Large    C0
# 6            7      F   Sports        Small    C0
# 7            8      F   Sports        Small    C0
# 8            9      F   Sports       Medium    C0
# 9           10      F   Luxury        Large    C0
# 10          11      M   Family        Large    C1
# 11          12      M   Family  Extra Large    C1
# 12          13      M   Family       Medium    C1
# 13          14      M   Luxury  Extra Large    C1
# 14          15      F   Luxury        Small    C1
# 15          16      F   Luxury        Small    C1
# 16          17      F   Luxury       Medium    C1
# 17          18      F   Luxury       Medium    C1
# ...

# %%
# Create X (fatures matrix)
X = dataset_mining.drop("Class", axis=1)

# Crate y (labels)
y =  dataset_mining["Class"]

# %%
# Choose the right modl and hyperparameters
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler
